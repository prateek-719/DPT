# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel("days")
plt.ylabel("temperature")
plt.title("Weather")
plt.plot(days,max_t,label="Max")
plt.plot(days,min_t,label="Min")
plt.plot(days,avg_t,label="Avg")
plt.legend(loc="lower left")
plt.grid()

# %%
xpos=np.arange(len(days))
xpos
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
plt.xticks(ypos,days)
plt.xlabel("Days")
plt.ylabel("Max")
plt.bar(ypos-0.4,max_t,label="Max")
plt.bar(ypos+0.4,min_t,label="Min")
plt.legend()

# %%
blood_sugar_men=[113,85,90,150,149,100,200,576,450]
blood_sugar_women=[150,100,985,125,90,80,90]
plt.hist([blood_sugar_men,blood_sugar_women],bins=2,color=['g','b'],label=['men','women'],orientation='horizontal')
plt.legend();

# %%
exp_vals=[1000,600,100,410,250]
exp_labels=['house rent','food','phone','car','other']
plt.pie(exp_vals,labels=exp_labels,radius=1,autopct='%0.0f%%',explode=[0,0,0,0.2,0])
plt.show()

# %%
plt.savefig("first.png")
